# %% [markdown]
# # To Ishaan -
# -  I will delete this once done with pipeline execution

# %%
# %sql
DROP TABLE IF EXISTS maven_market_uc.bronze_transactions;
DROP TABLE IF EXISTS maven_market_uc.bronze_stores;
DROP TABLE IF EXISTS maven_market_uc.bronze_regions;
DROP TABLE IF EXISTS maven_market_uc.bronze_returns;
DROP TABLE IF EXISTS maven_market_uc.bronze_calendar;
DROP TABLE IF EXISTS maven_market_uc.bronze_orders;
DROP TABLE IF EXISTS maven_market_uc.bronze_inventory;

# %%
display(
    spark.read.table("maven_market_uc.gold.fact_sales")
)

# %%
display(
    spark.read.table("maven_market_uc.gold.fact_returns")
)

# %%
display(
    spark.read.table("maven_market_uc.silver.silver_customers")
)

# %%
display(
    spark.read.table("maven_market_uc.silver.silver_scd_products")
    .select("product_id")
    .limit(5)
)

# %%
display(spark.read.table("maven_market_uc.silver.silver_scd_products"))

# %%
scopes = dbutils.secrets.listScopes()
for s in scopes:
    print(s.name)

for key in dbutils.secrets.list(scope="mongo-kafka-connector"):
    print(key.key)

# %%
dbutils.secrets.get(scope="mongo-kafka-connector", key="kafka-bootstrap")

# %%
# %sql
ALTER TABLE maven_market_uc.gold.gold_sales_daily
CLUSTER BY (store_id, product_id);

# %%
# %sql
