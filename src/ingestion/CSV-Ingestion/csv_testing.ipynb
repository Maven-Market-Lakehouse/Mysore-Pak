-- %%
SHOW TABLES IN maven_market_uc.bronze;

-- %%
select * from maven_market_uc.bronze.calendar limit 5;

-- %%
select * from maven_market_uc.bronze.regions limit 5;

-- %%
select * from maven_market_uc.bronze.returns limit 5;

-- %%
select * from maven_market_uc.bronze.stores limit 5;

-- %%
select * from maven_market_uc.bronze.transactions limit 5;

-- %%
SELECT COUNT(*) FROM maven_market_uc.bronze.transactions;

-- %%
%sql
describe table maven_market_uc.bronze.transactions;

-- %%
SELECT * FROM maven_market_uc.maven_market.customers LIMIT 10;

-- %%
SELECT * FROM maven_market_uc.maven_market.products LIMIT 10;

-- %%
SELECT COUNT(*) AS total_rows FROM maven_market_uc.maven_market.customers;

-- %%
SELECT COUNT(*) AS total_rows FROM maven_market_uc.maven_market.products;
